# %% [markdown]
# ### Step 1: Import Pandas and Numpy
#
# We will begin by importing the packages that we'll need to use with Python.
#
# We load pandas with `import pandas` and an extra `as pd` statement. This allows us to call functions from `pandas` with `pd.<function>` instead of `pandas.<function>` for convenience. `as pd` is **not** necessary to load the package.
#
# We also imported the `numpy` package, which is going to help pandas do some of its math.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Step 2: Import Your Dataset
#
# Input tabular data from a Comma Separated Values (csv) file into a dataframe object that we'll define as `df`.
#
# To create our dataframe object we'll define our object `df` by executing the `pd.read_csv()`function on our data file by inserting the relative file path into the parathenses.

# %%
df=pd.read_csv("global_power_plant_database.csv")

# %% [markdown]
# ### Step 3: Analyzing Data
#
# We will begin by looking at the columns and rows in out data, instead of the actual values.
#
# We will generally explore different variables with df. or df[] notation.
#
# Start by running df.columns, and then go into more specific data

# %%
df.columns
# Out:
# Index(['country', 'country_long', 'name', 'gppd_idnr', 'capacity_mw',
#        'latitude', 'longitude', 'primary_fuel', 'Unnamed: 8', 'Unnamed: 9',
#        'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'source', 'url',
#        'geolocation_source', 'wepp_id', 'year_of_capacity_data', 'Unnamed: 18',
#        'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22',
#        'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25',
#        'estimated_generation_gwh_2013', 'estimated_generation_gwh_2014',
#        'estimated_generation_gwh_2015', 'estimated_generation_gwh_2016',
#        'estimated_generation_gwh_2017', 'estimated_generation_note_2013',
#        'estimated_generation_note_2014', 'estimated_generation_note_2015',
#        'estimated_generation_note_2016', 'estimated_generation_note_2017'],
#       dtype='object')

# %% [markdown]
# This data shows us all the different variables we are working with. Go ahead and look through to see what can be used and what is unusable for this project.
#
# Once you have decided what is useable, begin to look at those specifically defined varaibles.

# %%
df.country_long
# Out:
# 0        Afghanistan
# 1        Afghanistan
# 2        Afghanistan
# 3        Afghanistan
# 4        Afghanistan
#             ...
# 34931         Zambia
# 34932         Zambia
# 34933         Zambia
# 34934       Zimbabwe
# 34935       Zimbabwe
# Name: country_long, Length: 34936, dtype: object

# %% [markdown]
# This function has pulled out all the dupplicates of countries that appear in the data.
#
# We can use the drop_duplicates function to find what is unique in each of these country values.

# %%
df.drop_duplicates("country_long")
# Out:
#       country    country_long                                          name  \
# 0         AFG     Afghanistan  Kajaki Hydroelectric Power Plant Afghanistan
# 9         ALB         Albania                                    Bistrica 1
# 17        DZA         Algeria                                         Adrar
# 76        AGO          Angola                                        Biopio
# 90        ATA      Antarctica                     McMurdo Station Generator
# ...       ...             ...                                           ...
# 34675     VNM         Vietnam                                        A Luoi
# 34911     ESH  Western Sahara          Dakhla IC Power Plant Western Sahara
# 34912     YEM           Yemen                                      Al Hiswa
# 34919     ZMB          Zambia                           Bancroft Copperbelt
# 34934     ZWE        Zimbabwe              Hwange Coal Power Plant Zimbabwe
#
#           gppd_idnr  capacity_mw  latitude  longitude primary_fuel  \
# 0      GEODB0040538         33.0   32.3220    65.1190        Hydro
# 9        WRI1002169         27.0   39.9116    20.1047        Hydro
# 17       WKS0068905         20.0   27.9080    -0.3170        Solar
# 76       WRI1023002         22.8  -12.4706    13.7319          Oil
# 90       WRI1023843          6.6  -77.8470   166.6605          Oil
# ...             ...          ...       ...        ...          ...
# 34675    WRI1030864        170.0   16.2266   107.2728        Hydro
# 34911  GEODB0042583         23.4   23.6816   -15.9594          Oil
# 34912    WRI1022444        125.0   12.8271    44.9227          Oil
# 34919    WRI1022387         20.0  -12.3786    27.8317          Oil
# 34934  GEODB0040404        920.0  -18.3835    26.4700         Coal
#
#        Unnamed: 8  Unnamed: 9  ...  estimated_generation_gwh_2013  \
# 0             NaN         NaN  ...                         123.77
# 9             NaN         NaN  ...                         105.17
# 17            NaN         NaN  ...                            NaN
# 76            NaN         NaN  ...                            NaN
# 90            NaN         NaN  ...                            NaN
# ...           ...         ...  ...                            ...
# 34675         NaN         NaN  ...                         660.65
# 34911         NaN         NaN  ...                            NaN
# 34912         NaN         NaN  ...                            NaN
# 34919         NaN         NaN  ...                            NaN
# 34934         NaN         NaN  ...                            NaN
#
#        estimated_generation_gwh_2014  estimated_generation_gwh_2015  \
# 0                             162.90                          97.39
# 9                              75.26                          79.50
# 17                             35.22                          34.22
# 76                               NaN                            NaN
# 90                               NaN                            NaN
# ...                              ...                            ...
# 34675                         622.22                         518.75
# 34911                            NaN                            NaN
# 34912                            NaN                            NaN
# 34919                            NaN                            NaN
# 34934                            NaN                            NaN
#
#       estimated_generation_gwh_2016 estimated_generation_gwh_2017  \
# 0                            137.76                        119.50
# 9                            105.45                         88.45
# 17                            35.33                         35.17
# 76                              NaN                         64.92
# 90                              NaN                           NaN
# ...                             ...                           ...
# 34675                        639.21                        374.44
# 34911                           NaN                           NaN
# 34912                           NaN                        268.32
# 34919                           NaN                         73.51
# 34934                           NaN                       2785.10
#
#       estimated_generation_note_2013 estimated_generation_note_2014  \
# 0                           HYDRO-V1                       HYDRO-V1
# 9                           HYDRO-V1                       HYDRO-V1
# 17                     NO-ESTIMATION                SOLAR-V1-NO-AGE
# 76                     NO-ESTIMATION                  NO-ESTIMATION
# 90                     NO-ESTIMATION                  NO-ESTIMATION
# ...                              ...                            ...
# 34675                       HYDRO-V1                       HYDRO-V1
# 34911                  NO-ESTIMATION                  NO-ESTIMATION
# 34912                  NO-ESTIMATION                  NO-ESTIMATION
# 34919                  NO-ESTIMATION                  NO-ESTIMATION
# 34934                  NO-ESTIMATION                  NO-ESTIMATION
#
#        estimated_generation_note_2015  estimated_generation_note_2016  \
# 0                            HYDRO-V1                        HYDRO-V1
# 9                            HYDRO-V1                        HYDRO-V1
# 17                    SOLAR-V1-NO-AGE                 SOLAR-V1-NO-AGE
# 76                      NO-ESTIMATION                   NO-ESTIMATION
# 90                      NO-ESTIMATION                   NO-ESTIMATION
# ...                               ...                             ...
# 34675                        HYDRO-V1                        HYDRO-V1
# 34911                   NO-ESTIMATION                   NO-ESTIMATION
# 34912                   NO-ESTIMATION                   NO-ESTIMATION
# 34919                   NO-ESTIMATION                   NO-ESTIMATION
# 34934                   NO-ESTIMATION                   NO-ESTIMATION
#
#        estimated_generation_note_2017
# 0                            HYDRO-V1
# 9                            HYDRO-V1
# 17                    SOLAR-V1-NO-AGE
# 76                 CAPACITY-FACTOR-V1
# 90                      NO-ESTIMATION
# ...                               ...
# 34675                        HYDRO-V1
# 34911                   NO-ESTIMATION
# 34912              CAPACITY-FACTOR-V1
# 34919              CAPACITY-FACTOR-V1
# 34934              CAPACITY-FACTOR-V1
#
# [167 rows x 36 columns]

# %% [markdown]
# ### Step 4: Filtering our date
#
# Now we will use specified functions to filter our data. This will help us focus on pulling the data we are actually going to use.

# %%
df.iloc[:,4] # All rows of column 4
# Out:
# 0         33.0
# 1         10.0
# 2         10.0
# 3         66.0
# 4        100.0
#          ...
# 34931     50.0
# 34932     20.0
# 34933    108.0
# 34934    920.0
# 34935    750.0
# Name: capacity_mw, Length: 34936, dtype: float64

# %%
df.loc[:,["country_long", "capacity_mw", "primary_fuel"]].sample(n=30)
# Out:
#                    country_long  capacity_mw  primary_fuel
# 5408                      China      400.000         Hydro
# 11548                    France        3.666       Biomass
# 1280                     Brazil       27.000          Wind
# 10426                    France        8.000         Hydro
# 11788                    France       10.400          Wind
# 4470                     Canada       80.000          Wind
# 1103                     Bhutan     1020.000         Hydro
# 17400                    Mexico        4.000       Biomass
# 33810  United States of America       12.000         Hydro
# 28803  United States of America        2.600           Gas
# 6834                      China       49.000          Wind
# 15931                      Iraq      250.000           Gas
# 6560                      China      950.000          Coal
# 20131               South Korea       80.000           Gas
# 32916  United States of America       58.200  Cogeneration
# 17802                 Nicaragua       27.200           Oil
# 21536                  Thailand        7.400         Solar
# 27907  United States of America        2.500           Gas
# 19122                   Romania       10.000         Solar
# 23175            United Kingdom        2.000         Solar
# 34322  United States of America      713.500          Coal
# 3731                     Canada       11.200         Hydro
# 29350  United States of America        2.000         Solar
# 18210                  Pakistan      131.000           Oil
# 5433                      China       98.800          Wind
# 21701                    Turkey       50.000          Wind
# 6032                      China     2000.000          Coal
# 34552                   Uruguay      212.000           Gas
# 32935  United States of America        1.000         Hydro
# 25346  United States of America        1.500         Solar
